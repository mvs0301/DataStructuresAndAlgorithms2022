# %% [markdown]
# <img src=../Img/banner_2.png>
#
# 28 октября 2022 года<br>
# Семинар, 15:40 - 17:10, 5-я пара<br>
# В4/3411(кк), 4-й Вешняковский проезд, 4<br>
# Группа БИ22-13
#
# Преподаватель: Смирнов Михаил Викторович, доцент Департамента Анализа данных и машинного обучения Финансового университета при Правительстве Российской Федерации
#
#
# # Текущий контроль успеваемости
#
# ## Выполните задания

# %% [markdown]
# <h3>Задание 1</h3> На основе строки "Берег моря" создайте словарь, в котором ключами будут номера букв, начиная от единицы, а значениями символы строки. Ожидается результат:
#
# ```{1: 'Б', 2: 'е', 3: 'р', 4: 'е', 5: 'г', 6: ' ', 7: 'м', 8: 'о', 9: 'р', 10: 'я'}```

# %%
# Задание 1. Ваш код здесь.

s="Берег моря"

# %% [markdown]
# <h3>Задание 2</h3> Имеется список списков в виде матрицы из $m$ строк и $n$ столбцов, например следующий список содержит три вложенных списка (три строки), в каждом из которых пять элементов (пять столбцов):
#
# ```
# [
# [1,2,3,4,5],
# ['a','b','c','d','e']
# ['*','+','-','//','%']
# ]
# ```
#
# Транспонируйте данный список так, так чтобы он содержал $n$ вложенных списков (строк) по $m$ элементов в каждом (столбцов). Ожидается результат:
#
# ```
# [
# [1,'a','*'],
# [2,'b','+'],
# [3,'c','-'],
# [4,'d','//'],
# [5,'e','%']
# ]
# ```

# %%
# Задание 2. Ваш код здесь.

lst1=[
[1,2,3,4,5],
['a','b','c','d','e'],
['*','+','-','//','%']
]

# %% [markdown]
# <h3>Задание 3</h3>
# Имеется список списков такой, что в первом вложенном списке содержится заголовок элементов на соответствующих позициях в остальных вложенных списках. Пример:
#
# ```
# [
# ["Family","Name","Father","Year"],
# ["Иванов","Иван","Иванович",1950],
# ["Петров","Петр","Петрович",1970],
# ["Сидоров","Ярослав","Кузьмич",1965],
# ["Кириенко","Александра","Валентиновна","1916"]
# ]
# ```
# Представьте эти данные в виде словаря, в котором ключами являются элементы первого списка, а значениями списки соответствующих элементов остальных списков. Ожидается результат в виде:
#
# ```
# {
# "Family":["Иванов","Петров","Сидоров","Кириенко"],
# "Name":["Иван","Петр","Ярослав","Александра"],
# "Father":["Иванович", ...],
# "Year":[...,1916]
# }
# ```

# %%
# Задание 3. Ваш код здесь.

lst2=[
["Family","Name","Father","Year"],
["Иванов","Иван","Иванович",1950],
["Петров","Петр","Петрович",1970],
["Сидоров","Ярослав","Кузьмич",1965],
["Кириенко","Александра","Валентиновна","1916"]
]

# %% [markdown]
# <h3>Задание 4</h3> Найдите точку $M=(x_{0},y_{0})$ максимума функции $f(x)$ в интервале $[a;b]$ с шагом $h$. Используйте следующие значения:
#
# $$f(x)=x \cdot sin(x-1), a=-\pi, b=\pi, h=0.1$$
#
# Результат округлите до двух десятичных знаков. Ожидается ответ:
#
# ```
# Точка максимума функции M=(<x>,<y>)
# ```

# %%
# Задание 4. Ваш код здесь.

# %% [markdown]
# <h3> Задание 5</h3>
# Создайте функцию, которая рисует следующий V-образный узор размера $k \times 2k$, например $7 \times 14$
#
# ```
# *            *
# **          **
# ***        ***
# ****      ****
# *****    *****
# ******  ******
# **************
# ```
#
# или $5 \times 10$
#
# ```
# ^        ^
# ^^      ^^
# ^^^    ^^^
# ^^^^  ^^^^
# ^^^^^^^^^^
# ```
#
# разными символами. Функция должна иметь два параметра: число $k$ и символ, используемый для рисования.

# %%
# Задание 5. Ваш код здесь.

# %% [markdown]
# <h3>Задание 6</h3>
#
# Отсортируйте кортеж
#
# ```
# flowers = (('розы', 23),('гладиолусы', 37),('фиалки', 11),('ромашки',29))
# ```
#
# по второму значению в порядке возрастания с помощью функций `sorted()` и `lambda`. С этой целью завершите написание программы, подставив свой код вместо знака вопроса.
#
# ```
# sorted(flowers, key=lambda x : ?)
# ```
#
# Распечатайте результат в виде:
# ```
# (('фиалки', 11), ('розы', 23), ('ромашки', 29), ('гладиолусы', 37))
# ```

# %%
# Задание 6. Ваш код здесь.

flowers = (('розы', 23),('гладиолусы', 37),('фиалки', 11),('ромашки',29))

# %% [markdown]
# <h3>Задание 7</h3>
#
# Для приготовления блюд национальной кухни используются следующие продукты (ingredients):
#
# ```
# ingredients={
#     "indian":["vegetable oil","wheat","black pepper",
#               "cayenne pepper","onions","milk","butter","sugar",
#               "salt","lemon","natural yogurt","carrots","rice"],
#     "chinese":["sesame oil","black pepper",
#                "cayenne pepper","canola oil","sugar",
#                "garlic","red pepper","yellow peppers","broccoli",
#                "green bell pepper","vegetable oil","eggs","onions","rice"],
#     "korean":["daikon","red radishes","onions","salt","carrots",
#               "garlic","black pepper","eggs"]
# }
# ```
#
# a) Сколько всего различных продуктов входит в состав разных кухонь?<br>
# б) Перечислите продукты, которые входят в состав только одной кухни, сколько таких продуктов?<br>
# в) Найдите все виды перца (pepper) используемые во всех кухнях.<br>

# %%
# Задание 7. Ваш код здесь

ingredients={
    "indian":["vegetable oil","wheat","black pepper",
              "cayenne pepper","onions","milk","butter","sugar",
              "salt","lemon","natural yogurt","carrots","rice"],
    "chinese":["sesame oil","black pepper",
               "cayenne pepper","canola oil","sugar",
               "garlic","red pepper","yellow peppers","broccoli",
               "green bell pepper","vegetable oil","eggs","onions","rice"],
    "korean":["daikon","red radishes","onions","salt","carrots",
              "garlic","black pepper","eggs"]
}

# %% [markdown]
# <h3>Задание 8</h3> Укажите правильный ответ.
#
# 3.1. Что делает метод `pop()` списка?
# - Удаляет элемент списка по значению
# - Удаляет элемент списка по индексу
# - Удаляет случайный элемент списка и возвращает его значение
# - Восстанавивает последнний удаленный элемент списка
# - Нет правильного ответа
#
# 3.2. Что делает метод `remove()` множества?
# - Удаляет элемент множества по значению
# - Удаляет элемент множества по индексу
# - Удаляет все элементы множества
# - Удаляет случайный элемент множества и возвращает его значение
# - Нет правильного ответа
#
# 3.3. Что делает метод `pop()` словаря?
# - Удаляет элемент словаря по ключу
# - Удаляет элемент словаря по значению
# - Удаляет все элементы словаря
# - Удаляет случайный элемент словаря и возвращает его значение
# - Нет правильного ответа

# %%
# Задание 8. Ваш ответ здесь.

"""

"""
